# %% [markdown]
# <a href="https://colab.research.google.com/github/FatimaZehra19/ML-Learning-Journey/blob/main/Python_Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Mad Lib Game**

# %%
color = input("Enter a Color: ")
plural_noun = input("Enter a plural noun: ")
a_person = input("Enter a a person: ")
print ("Roses are " + (color) )
print ((plural_noun) + " are Blue")
print ("I like " + (a_person) )
# Out:
# Enter a Color: Red
# Enter a plural noun: Voilets
# Enter a a person: Tom
# Roses are Red
# Voilets are Blue
# I like Tom

# %% [markdown]
# **Lists**
#
# *  We refered to the individual elements of list using thier idex number.
#
# *  When we use colons the the last number is not included.

# %%
friends = ["Mishal" , "Azfar" , "Fatima"]
print(friends[0])

friends = ["Mishal" , "Azfar" , "Fatima"]
print(friends[-1])

friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman"]
print(friends[1:3])

friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman"]
friends[2] = "Azfar"
print(friends[2])
# Out:
# Mishal
# Fatima
# ['Azfar', 'Fatima']
# Azfar

# %% [markdown]
# **List Functions**
#
#
#
# * **Extend**: It Extend the list.
# * **Append**: It can add more elements to list.
# * **Insert**: It insert an elements in the list on mentioned index.
# * **Remove**: It can remove the elemnet from the list.
# * **Clear**: It clears the list.
# * **Pop**: It removes the last element of the list.
# * **Index**: It tell the index number of mentioned element.
# * **Sort**: It can sort the list.
# * **Reverse**: It reverse the list.
# * **Copy**: It can make another list using previous one.

# %%
lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman"]
friends.extend(lucky_numbers)
print(friends)


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman"]
friends.append("Fizza")
print(friends)


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman"]
friends.insert (2, "Askari")
print(friends)


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza"]
friends.remove("Fizza")
print(friends)



lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza"]
friends.clear()
print(friends)


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza"]
friends.pop()
print(friends)


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza"]

print(friends.index("Fizza"))


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza", "Fatima", "Fatima"]

print(friends.count("Fatima"))


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza", "Fatima", "Fatima"]
lucky_numbers.sort()
print(lucky_numbers)


lucky_numbers =[4,3,2,5,7,8,6,4,]
friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza", "Fatima", "Fatima"]
lucky_numbers.reverse()
print(lucky_numbers)



friends = ["Mishal" , "Azfar" , "Fatima" , "Aiman" , "Fizza", "Fatima", "Fatima"]
friends2 = friends.copy()
print(friends2)
# Out:
# ['Mishal', 'Azfar', 'Fatima', 'Aiman', 4, 3, 2, 5, 7, 8, 6, 4]
# ['Mishal', 'Azfar', 'Fatima', 'Aiman', 'Fizza']
# ['Mishal', 'Azfar', 'Askari', 'Fatima', 'Aiman']
# ['Mishal', 'Azfar', 'Fatima', 'Aiman']
# []
# ['Mishal', 'Azfar', 'Fatima', 'Aiman']
# 4
# 3
# [2, 3, 4, 4, 5, 6, 7, 8]
# [4, 6, 8, 7, 5, 2, 3, 4]
# ['Mishal', 'Azfar', 'Fatima', 'Aiman', 'Fizza', 'Fatima', 'Fatima']

# %% [markdown]
# **Tuples**:A container where we can store different values.
# * Tuples are immutable which means it cann't be changed or modified.
# * In Python, The difference between lists and tuples are of brackets. In lists we use Square brackes whereas in tuple we use round brackets.

# %%
coordinates =(4 , 5)

print(coordinates[0])
# Out:
# 4

# %% [markdown]
# **Tuples inside the list**
# * It can be modified.

# %%
coordinates =[(4 , 5), (4,7) , (7,9)]
coordinates[1] = 10
print(coordinates[1])
# Out:
# 10

# %% [markdown]
# **Functions**: Collection of code which performs operations.
# * When we want to write function we first write def.

# %%
def say_hi():
  print("Hello User!")

say_hi()
# Out:
# Hello User!

# %% [markdown]
# **Parameter**: Piece of information that we give o function.

# %%
def say_hi(name, age):
  print("Hello User! " + name + " You are " +str(age) )

say_hi("Fatima", 25)
say_hi("Azfar", 30)
# Out:
# Hello User! Fatima You are 25
# Hello User! Azfar You are 30

# %% [markdown]
# **Return Statement**

# %%
def cube(num):
    return num*num*num

result = cube(4)
print (result)
# Out:
# 64

# %% [markdown]
# **If Statments**

# %%
is_female = False
is_tall = False
if is_female or is_tall :
  print("You are Female or tall or both")
else:
  print("You are niether Female nor tall")


is_female = True
is_tall = True
if is_female and is_tall :
  print("You are Female and tall")
else:
  print("You are either Female nor tall")
# Out:
# You are niether Female nor tall
# You are Female and tall

# %%
is_female = True
is_tall = False

if is_female or is_tall :
  print("You are tall Female  ")
elif is_female and not(is_tall):
  print("You are short female")
elif not(is_female) and is_tall:
  print("You are not female but tall")
else:
  print("You are niether Female nor tall")
# Out:
# You are tall Female

# %% [markdown]
# **If Statments and Comparisons**

# %%
def max_num(num1, num2 , num3):
  if num1 >= num2 and num1 >= num3:
    return num1
  elif num2 >= num1 and num2 >= num3:
    return num2
  else:
    return num3

print(max_num(300,445,32))
# Out:
# 445
